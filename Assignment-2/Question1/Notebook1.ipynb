# %% [markdown]
# # Question 1

# %% [markdown]
# ### (a)  Find the frequencies of POS tags of words

# %%
# Here we import parse to parsing the conllu file 
from conllu import parse

# %%
#open the conllu file
with open('hi_hdtb-ud-train.conllu', "r", encoding="utf-8") as file:
    data_file = file.read()
sentences = parse(data_file)

# %%
#finding the pos_tag of words
pos_tag_freq={}
for words in sentences:
    for word in words:
        if  (word['upos']) not in  pos_tag_freq.keys():
            pos_tag_freq[word['upos']]=1
        else:
            pos_tag_freq[word['upos']]+=1
            
            
pos_tag_freq = sorted(pos_tag_freq.items(), key=lambda x:x[1],reverse=True)
print(pos_tag_freq)
# Out:
# [('NOUN', 62191), ('ADP', 59221), ('PROPN', 34289), ('VERB', 27188), ('AUX', 20821), ('PUNCT', 18668), ('ADJ', 16459), ('PRON', 11857), ('DET', 6081), ('PART', 5610), ('SCONJ', 5389), ('NUM', 5332), ('CCONJ', 5110), ('ADV', 2703), ('X', 135), ('INTJ', 3)]

# %% [markdown]
# ### (b) list the 50 most frequent words corresponding to each POS tag

# %%
#import counter for counting
#finding the dictionary contain the pos tag with corresponding words
from collections import Counter
lemma = {}
for words in sentences:
    for word in words:
        list1 = lemma.get(word['upos'], [])
        list1.append(word['form'])
        lemma[word['upos']]= list1

# %%
#Here sort the lemma dict and save into another dict lemma2
lemma2 = {}
for k,v in lemma.items():
    temp1 = dict(Counter(v))
    marklist = sorted(temp1.items(), key=lambda x:x[1],reverse=True)
    lemma2[k] = marklist

# %%
# finding most frequent words corresponding to each pos_tag
for p,q in lemma2.items():
    lemma2[p]=q[:50]
lemma2
# Out:
# {'DET': [('इस', 1917),
#   ('यह', 658),
#   ('इन', 373),
#   ('कुछ', 347),
#   ('कई', 308),
#   ('सभी', 267),
#   ('कम', 178),
#   ('ज्यादा', 165),
#   ('काफी', 147),
#   ('उस', 132),
#   ('अधिक', 131),
#   ('इसी', 127),
#   ('और', 125),
#   ('हर', 109),
#   ('ये', 104),
#   ('ऐसे', 76),
#   ('जो', 62),
#   ('उन', 61),
#   ('ऐसी', 55),
#   ('बहुत', 54),
#   ('जिस', 53),
#   ('ऐसा', 49),
#   ('कुल', 44),
#   ('यही', 38),
#   ('तमाम', 31),
#   ('उसी', 28),
#   ('जिन', 27),
#   ('अनेक', 25),
#   ('क्या', 23),
#   ('प्रत्येक', 23),
#   ('किस', 22),
#   ('हम', 20),
#   ('सारी', 16),
#   ('अधिकांश', 16),
#   ('आधा', 16),
#   ('इतना', 13),
#   ('वह', 13),
#   ('सारा', 13),
#   ('इतने', 12),
#   ('इतनी', 12),
#   ('वही', 12),
#   ('थोड़ी', 12),
#   ('कितने', 11),
#   ('आधे', 11),
#   ('सारे', 11),
#   ('कितनी', 10),
#   ('इन्हीं', 9),
#   ('वे', 9),
#   ('उन्हीं', 8),
#   ('किन', 8)],
#  'PROPN': [('भारत', 693),
#   ('सिंह', 656),
#   ('प्रधानमंत्री', 419),
#   ('कांग्रेस', 405),
#   ('पाकिस्तान', 393),
#   ('दिल्ली', 345),
#   ('मंत्री', 336),
#   ('भाजपा', 331),
#   ('सरकार', 247),
#   ('केंद्र', 227),
#   ('कश्मीर', 226),
#   ('प्रदेश', 203),
#   ('मुख्यमंत्री', 203),
#   ('मनमोहन', 188),
#   ('मंत्रालय', 183),
#   ('राष्ट्रपति', 182),
#   ('गांधी', 170),
#   ('के.', 170),
#   ('बिहार', 168),
#   ('बुधवार', 153),
#   ('अमेरिका', 149),
#   ('उत्तर', 148),
#   ('मंगलवार', 140),
#   ('मुंबई', 134),
#   ('शनिवार', 128),
#   ('यूपीए', 127),
#   ('विदेश', 125),
#   ('सोमवार', 124),
#   ('आडवाणी', 123),
#   ('सोनिया', 123),
#   ('बृहस्पतिवार', 121),
#   ('जम्मू', 117),
#   ('केंद्रीय', 114),
#   ('शुक्रवार', 109),
#   ('लालू', 109),
#   ('यादव', 108),
#   ('पी.', 107),
#   ('राजग', 105),
#   ('मुशर्रफ', 105),
#   ('भारतीय', 103),
#   ('एस.', 101),
#   ('रविवार', 100),
#   ('राष्ट्रीय', 96),
#   ('कोर्ट', 89),
#   ('कुमार', 89),
#   ('जून', 84),
#   ('आयोग', 82),
#   ('सुप्रीम', 80),
#   ('उमा', 77),
#   ('राज्यपाल', 76)],
#  'ADP': [('के', 12669),
#   ('में', 8416),
#   ('की', 6476),
#   ('को', 6006),
#   ('ने', 4889),
#   ('से', 4653),
#   ('का', 3514),
#   ('पर', 3238),
#   ('लिए', 1773),
#   ('तक', 673),
#   ('साथ', 609),
#   ('बाद', 544),
#   ('वाले', 422),
#   ('द्वारा', 398),
#   ('बारे', 320),
#   ('बीच', 310),
#   ('दौरान', 283),
#   ('मुताबिक', 272),
#   ('वाली', 236),
#   ('कारण', 231),
#   ('खिलाफ', 230),
#   ('पहले', 214),
#   ('ओर', 203),
#   ('अलावा', 191),
#   ('पास', 169),
#   ('तहत', 158),
#   ('अनुसार', 151),
#   ('रूप', 108),
#   ('जरिए', 97),
#   ('समेत', 95),
#   ('सामने', 77),
#   ('बावजूद', 77),
#   ('जैसे', 74),
#   ('वजह', 72),
#   ('समय', 66),
#   ('बाहर', 56),
#   ('चलते', 54),
#   ('सहित', 54),
#   ('प्रति', 52),
#   ('वाला', 51),
#   ('तरह', 49),
#   ('वालों', 49),
#   ('अंदर', 43),
#   ('समक्ष', 39),
#   ('मद्देनजर', 38),
#   ('पूर्व', 37),
#   ('पीछे', 33),
#   ('भीतर', 31),
#   ('ऊपर', 30),
#   ('जैसी', 30)],
#  'ADV': [('बाद', 359),
#   ('पहले', 160),
#   ('फिर', 136),
#   ('सबसे', 135),
#   ('वहीं', 98),
#   ('आगे', 86),
#   ('जल्द', 76),
#   ('साथ', 71),
#   ('लगातार', 65),
#   ('फिलहाल', 65),
#   ('बहुत', 62),
#   ('दौरान', 55),
#   ('सामने', 48),
#   ('जमकर', 48),
#   ('दूर', 45),
#   ('दोबारा', 45),
#   ('बीच', 43),
#   ('बाहर', 39),
#   ('बेहद', 32),
#   ('बार', 30),
#   ('तत्काल', 29),
#   ('दरअसल', 27),
#   ('पीछे', 27),
#   ('हमेशा', 24),
#   ('शीघ्र', 24),
#   ('जहां', 23),
#   ('तुरंत', 23),
#   ('जरूर', 22),
#   ('अचानक', 22),
#   ('काफी', 21),
#   ('ओर', 21),
#   ('अलग', 20),
#   ('जैसे', 18),
#   ('और', 18),
#   ('पूर्व', 18),
#   ('खासकर', 18),
#   ('लिहाजा', 18),
#   ('शायद', 17),
#   ('पास', 17),
#   ('ऊपर', 15),
#   ('नीचे', 15),
#   ('सर्वाधिक', 14),
#   ('उधर', 14),
#   ('धीरे', 14),
#   ('वैसे', 13),
#   ('एकजुट', 13),
#   ('अंदर', 12),
#   ('सीधे', 12),
#   ('आखिर', 12),
#   ('इधर', 12)],
#  'ADJ': [('शामिल', 277),
#   ('अन्य', 245),
#   ('जारी', 239),
#   ('पिछले', 220),
#   ('पूर्व', 218),
#   ('भारतीय', 202),
#   ('तैयार', 182),
#   ('पूरी', 167),
#   ('स्थित', 153),
#   ('वरिष्ठ', 145),
#   ('दर्ज', 133),
#   ('पूरा', 127),
#   ('पेश', 125),
#   ('अलग', 120),
#   ('अगले', 113),
#   ('राजनीतिक', 109),
#   ('विशेष', 107),
#   ('अमेरिकी', 107),
#   ('बंद', 104),
#   ('मुख्य', 99),
#   ('गौरतलब', 98),
#   ('सरकारी', 96),
#   ('प्रभावित', 94),
#   ('पूरे', 91),
#   ('तय', 91),
#   ('नए', 91),
#   ('मौजूद', 89),
#   ('पाकिस्तानी', 88),
#   ('विभिन्न', 87),
#   ('नई', 86),
#   ('वापस', 86),
#   ('राष्ट्रीय', 84),
#   ('आयोजित', 81),
#   ('लागू', 81),
#   ('बड़े', 80),
#   ('पहली', 80),
#   ('अंतिम', 80),
#   ('गिरफ्तार', 80),
#   ('दूसरे', 78),
#   ('उपलब्ध', 76),
#   ('महत्वपूर्ण', 75),
#   ('बड़ी', 74),
#   ('केंद्रीय', 73),
#   ('अंतर्राष्ट्रीय', 71),
#   ('प्रमुख', 70),
#   ('जरूरी', 70),
#   ('आम', 69),
#   ('स्थानीय', 68),
#   ('घायल', 67),
#   ('आर्थिक', 67)],
#  'NOUN': [('सरकार', 768),
#   ('पुलिस', 534),
#   ('लोगों', 511),
#   ('पार्टी', 407),
#   ('मामले', 385),
#   ('बात', 366),
#   ('तरह', 323),
#   ('राज्य', 320),
#   ('चुनाव', 320),
#   ('देश', 313),
#   ('बैठक', 307),
#   ('समय', 281),
#   ('अध्यक्ष', 273),
#   ('शुरू', 270),
#   ('साल', 254),
#   ('लोग', 242),
#   ('रुपये', 242),
#   ('दिन', 232),
#   ('बातचीत', 227),
#   ('क्षेत्र', 226),
#   ('सुरक्षा', 223),
#   ('नेता', 220),
#   ('नेताओं', 219),
#   ('जानकारी', 214),
#   ('सूत्रों', 212),
#   ('काम', 206),
#   ('जांच', 202),
#   ('बार', 198),
#   ('देशों', 190),
#   ('वर्ष', 189),
#   ('आज', 186),
#   ('रिपोर्ट', 186),
#   ('प्रस्ताव', 180),
#   ('अधिकारियों', 178),
#   ('फैसला', 178),
#   ('अदालत', 177),
#   ('मुद्दे', 175),
#   ('रूप', 173),
#   ('अधिकारी', 169),
#   ('आरोप', 168),
#   ('मांग', 168),
#   ('फीसदी', 166),
#   ('नाम', 164),
#   ('राज्यों', 164),
#   ('विचार', 158),
#   ('बयान', 150),
#   ('यात्रा', 143),
#   ('योजना', 140),
#   ('पद', 133),
#   ('स्थिति', 130)],
#  'NUM': [('एक', 1348),
#   ('दो', 400),
#   ('दोनों', 316),
#   ('तीन', 257),
#   ('करोड़', 155),
#   ('चार', 147),
#   ('लाख', 141),
#   ('हजार', 125),
#   ('पांच', 113),
#   ('छह', 84),
#   ('सात', 70),
#   ('१०', 58),
#   ('२०', 56),
#   ('दस', 48),
#   ('१५', 46),
#   ('आठ', 43),
#   ('५०', 38),
#   ('सौ', 36),
#   ('१२', 36),
#   ('२५', 35),
#   ('११', 27),
#   ('६०', 26),
#   ('नौ', 25),
#   ('तीनों', 24),
#   ('अरब', 24),
#   ('५', 22),
#   ('डेढ़', 21),
#   ('१००', 21),
#   ('हजारों', 19),
#   ('४०', 19),
#   ('१४', 19),
#   ('३०', 19),
#   ('सैकड़ों', 18),
#   ('साढ़े', 18),
#   ('६', 18),
#   ('१८', 17),
#   ('ढाई', 15),
#   ('10', 14),
#   ('करोड़ों', 14),
#   ('२४', 13),
#   ('३५', 13),
#   ('२१', 12),
#   ('१३', 12),
#   ('९.५', 12),
#   ('शून्य', 12),
#   ('३२', 11),
#   ('पचास', 11),
#   ('४', 11),
#   ('बीस', 10),
#   ('लाखों', 10)],
#  'AUX': [('है', 6289),
#   ('हैं', 2065),
#   ('गया', 1268),
#   ('था', 902),
#   ('गई', 713),
#   ('गए', 650),
#   ('हुए', 646),
#   ('थी', 586),
#   ('जा', 566),
#   ('दिया', 566),
#   ('रहे', 533),
#   ('थे', 497),
#   ('रही', 486),
#   ('रहा', 421),
#   ('जाने', 379),
#   ('दी', 316),
#   ('चाहिए', 292),
#   ('जाएगा', 287),
#   ('सकता', 230),
#   ('लिया', 178),
#   ('जाता', 153),
#   ('सकते', 144),
#   ('जाएगी', 143),
#   ('सकती', 139),
#   ('जाए', 120),
#   ('कर', 106),
#   ('चुके', 103),
#   ('जाना', 92),
#   ('होगा', 75),
#   ('सके', 74),
#   ('ली', 71),
#   ('थीं', 65),
#   ('चुकी', 64),
#   ('पड़ा', 64),
#   ('हुआ', 62),
#   ('चुका', 61),
#   ('जाती', 58),
#   ('जाएंगे', 49),
#   ('दिए', 44),
#   ('जाते', 38),
#   ('हुई', 38),
#   ('हूं', 37),
#   ('गयी', 34),
#   ('सका', 30),
#   ('पड़ी', 30),
#   ('जानी', 30),
#   ('पाई', 25),
#   ('पाया', 24),
#   ('हो', 23),
#   ('लिए', 22)],
#  'PUNCT': [('।', 12160),
#   (',', 2572),
#   ('-', 1232),
#   ('.', 1008),
#   ("'", 585),
#   ('(', 439),
#   (')', 439),
#   ('-JOIN', 98),
#   ('?', 66),
#   ("'1", 30),
#   ("'2", 23),
#   ('"', 4),
#   (':', 3),
#   ('...', 2),
#   ('!', 2),
#   ('/', 2),
#   ('....', 1),
#   ('......', 1),
#   (':-', 1)],
#  'PRON': [('उन्होंने', 1197),
#   ('यह', 573),
#   ('इसके', 546),
#   ('अपने', 495),
#   ('कोई', 494),
#   ('वह', 492),
#   ('उनके', 381),
#   ('उन्हें', 369),
#   ('अब', 362),
#   ('अपनी', 361),
#   ('किसी', 356),
#   ('वे', 264),
#   ('उनकी', 255),
#   ('इससे', 239),
#   ('यहां', 231),
#   ('इस', 212),
#   ('जब', 207),
#   ('उसके', 177),
#   ('अभी', 177),
#   ('जो', 174),
#   ('उसे', 170),
#   ('यहाँ', 162),
#   ('इसमें', 152),
#   ('वहां', 148),
#   ('हम', 146),
#   ('इसे', 140),
#   ('इसका', 131),
#   ('अपना', 128),
#   ('उनका', 128),
#   ('तो', 120),
#   ('इसकी', 110),
#   ('कुछ', 107),
#   ('उसने', 103),
#   ('जिसमें', 100),
#   ('इसलिए', 92),
#   ('उसकी', 92),
#   ('क्या', 84),
#   ('खुद', 77),
#   ('इनमें', 75),
#   ('आप', 74),
#   ('ऐसा', 73),
#   ('हमें', 69),
#   ('तब', 66),
#   ('जिससे', 66),
#   ('मैं', 66),
#   ('जहां', 63),
#   ('उसका', 60),
#   ('कभी', 50),
#   ('जिसके', 50),
#   ('जिसे', 45)],
#  'VERB': [('कहा', 2203),
#   ('किया', 1371),
#   ('कर', 1313),
#   ('करने', 1176),
#   ('की', 988),
#   ('हो', 871),
#   ('है', 623),
#   ('बताया', 581),
#   ('होने', 517),
#   ('हुई', 366),
#   ('करते', 346),
#   ('दिया', 338),
#   ('देने', 319),
#   ('किए', 294),
#   ('लेकर', 274),
#   ('दी', 274),
#   ('कहना', 268),
#   ('करना', 228),
#   ('हुआ', 198),
#   ('हुए', 189),
#   ('दे', 182),
#   ('बनाने', 161),
#   ('होगा', 155),
#   ('करेंगे', 152),
#   ('ले', 139),
#   ('आने', 133),
#   ('दिए', 130),
#   ('होगी', 128),
#   ('लेने', 126),
#   ('लगा', 118),
#   ('लिया', 116),
#   ('आए', 110),
#   ('चल', 110),
#   ('जाने', 109),
#   ('लगाया', 109),
#   ('आ', 106),
#   ('मिल', 106),
#   ('मिलने', 106),
#   ('मारे', 103),
#   ('कराने', 102),
#   ('देते', 100),
#   ('रखा', 99),
#   ('चाहते', 94),
#   ('हैं', 93),
#   ('मिली', 93),
#   ('माना', 88),
#   ('बनाया', 85),
#   ('रखने', 84),
#   ('लगाने', 84),
#   ('बढ़ाने', 82)],
#  'CCONJ': [('और', 3097),
#   ('व', 639),
#   ('लेकिन', 597),
#   ('जबकि', 204),
#   ('या', 185),
#   ('तथा', 179),
#   ('पर', 90),
#   ('एवं', 66),
#   ('अथवा', 17),
#   ('मगर', 16),
#   ('लिहाजा', 6),
#   ('अतः', 4),
#   ('परंतु', 4),
#   ('किंतु', 3),
#   ('औऱ', 2),
#   ('लिहाज़ा', 1)],
#  'PART': [('भी', 1874),
#   ('नहीं', 1612),
#   ('ही', 955),
#   ('न', 178),
#   ('तो', 148),
#   ('करीब', 134),
#   ('से', 93),
#   ('लगभग', 74),
#   ('भर', 72),
#   ('सिर्फ', 60),
#   ('केवल', 48),
#   ('बिना', 46),
#   ('प्रति', 37),
#   ('कि', 30),
#   ('बगैर', 26),
#   ('आदि', 24),
#   ('फिर', 20),
#   ('उर्फ', 19),
#   ('तकरीबन', 16),
#   ('मात्र', 15),
#   ('ठीक', 14),
#   ('महज', 13),
#   ('तुरंत', 11),
#   ('सा', 9),
#   ('सी', 8),
#   ('जी', 6),
#   ('जैसे', 4),
#   ('मत', 4),
#   ('गुना', 4),
#   ('तत्काल', 4),
#   ('भले', 4),
#   ('में', 4),
#   ('फौरन', 4),
#   ('बस', 3),
#   ('क़रीब', 3),
#   ('तक़रीबन', 3),
#   ('वगैरह', 2),
#   ('तक', 2),
#   ('बी', 2),
#   ('अमूमन', 2),
#   ('बग़ैर', 2),
#   ('जरा', 1),
#   ('भी...', 1),
#   ('भला', 1),
#   ('जैसा', 1),
#   ('सि\u200dर्फ़', 1),
#   ('सिवा', 1),
#   ('उर्फ़', 1),
#   ('साहब', 1),
#   ('अकेले', 1)],
#  'SCONJ': [('कि', 4391),
#   ('तो', 295),
#   ('हालांकि', 171),
#   ('अगर', 117),
#   ('यदि', 107),
#   ('क्योंकि', 107),
#   ('ताकि', 53),
#   ('बहरहाल', 45),
#   ('बल्कि', 21),
#   ('यानि', 17),
#   ('चूंकि', 16),
#   ('अलबत्ता', 11),
#   ('हालाँकि', 6),
#   ('यानी', 6),
#   ('यद्यपि', 5),
#   ('जैसा', 5),
#   ('जैसे', 4),
#   ('अन्यथा', 3),
#   ('वरना', 3),
#   ('बशर्ते', 2),
#   ('अर्थात', 2),
#   ('जो', 1),
#   ('वर्ना', 1)],
#  'X': [('पास', 16),
#   ('रिकॉर्ड', 9),
#   ('डाउनलोड', 5),
#   ('बुक', 4),
#   ('फेल', 4),
#   ('आफ', 3),
#   ('लीक', 3),
#   ('आउट', 3),
#   ('फिट', 3),
#   ('रेफर', 3),
#   ('सील', 3),
#   ('रिलीज', 2),
#   ('कैंसिल', 2),
#   ('रिटर्न', 2),
#   ('ब्लैकमेल', 2),
#   ('बड़े', 2),
#   ('लांच', 2),
#   ('अपने', 2),
#   ('बार', 2),
#   ('अलॉट', 2),
#   ('रिकार्ड', 2),
#   ('अलग', 2),
#   ('वाकआउट', 2),
#   ('लेट', 2),
#   ('सूट', 1),
#   ('प्रमोट', 1),
#   ('फिक्स', 1),
#   ('ओरिजनल', 1),
#   ('हैक', 1),
#   ('साथ', 1),
#   ('बडे', 1),
#   ('दर्जन', 1),
#   ('कभी', 1),
#   ('डिजाइन', 1),
#   ('सीज', 1),
#   ('गरज', 1),
#   ('हैंडल', 1),
#   ('क्लिक', 1),
#   ('रिटायर', 1),
#   ('डिफ्यूज', 1),
#   ('नोट', 1),
#   ('ऑनलाइन', 1),
#   ('क्रॉस', 1),
#   ('शूट', 1),
#   ('ओके', 1),
#   ('क्रास', 1),
#   ('डेटोनेट', 1),
#   ('फाइल', 1),
#   ('अंडरग्रेजुएट', 1),
#   ('टेस्ट', 1)],
#  'INTJ': [('ऐ', 2), ('वाह', 1)]}

# %% [markdown]
# ### (c) Find the frequencies of gender, case and number of words separately

# %%
dict1={}
for words in sentences:
    for word in words:
        dict1[word['form']]=word['feats']

# %%
# finding the gender_freq
gender_freq={}
for key,value in dict1.items():
    if value is not None:
        for x,y in value.items():
            if x=='Gender':
                    if y in gender_freq:
                        gender_freq[y]+=1
                    else:
                        gender_freq[y]=1
            else:
                continue

# %%
gender_freq
# Out:
# {'Masc': 9413, 'Fem': 3387}

# %%
#finding the case freq
case_freq={}
for key,value in dict1.items():
    if value is not None:
        for x,y in value.items():
            if x=='Case':
                    if y in case_freq:
                        case_freq[y]+=1
                    else:
                        case_freq[y]=1
            else:
                continue

# %%
case_freq
# Out:
# {'Nom': 6539,
#  'Acc': 7013,
#  'Acc,Dat': 19,
#  'Acc,Gen': 34,
#  'Acc,Ine': 7,
#  'Acc,Ins': 8,
#  'Acc,Erg': 14}

# %%
number_freq={}
for key,value in dict1.items():
     if value is not None:
        for x,y in value.items():
            if x=='Number':
                    if y in number_freq:
                        number_freq[y]+=1
                    else:
                        number_freq[y]=1
            else:
                continue

# %%
number_freq
# Out:
# {'Sing': 11398, 'Plur': 2266}

# %% [markdown]
# ### (d)  List the 50 most frequent combinations of gender, case and number as a 3-tuple.

# %%
#Here find the dict with combinations of gender,case,number 
G_C_N={}
for key,value in dict1.items():
    if value is not None :
        if(value.keys() >= { "Case","Gender","Number"}):
            
            if (value['Gender'],value['Case'],value['Number']) not in G_C_N.keys():
                G_C_N[(value['Gender'],value['Case'],value['Number'])]=1
            else:
                G_C_N[(value['Gender'],value['Case'],value['Number'])]= G_C_N[(value['Gender'],value['Case'],value['Number'])]+1

        else:
            continue

G_C_N= sorted(G_C_N.items(), key=lambda x:x[1],reverse=True)
G_C_N
# Out:
# [(('Masc', 'Nom', 'Sing'), 4108),
#  (('Masc', 'Acc', 'Sing'), 3201),
#  (('Fem', 'Nom', 'Sing'), 1232),
#  (('Fem', 'Acc', 'Sing'), 1125),
#  (('Masc', 'Acc', 'Plur'), 903),
#  (('Fem', 'Acc', 'Plur'), 330),
#  (('Masc', 'Nom', 'Plur'), 321),
#  (('Fem', 'Nom', 'Plur'), 249),
#  (('Masc', 'Acc,Gen', 'Sing'), 12),
#  (('Fem', 'Acc,Gen', 'Sing'), 7),
#  (('Masc', 'Acc,Gen', 'Plur'), 3),
#  (('Fem', 'Acc,Gen', 'Plur'), 3)]

# %% [markdown]
# ### (e)  Find the frequencies of POS tags corresponding to only head words.

# %%
# here finding the dict contain pos tag with corresponding head_word
head_word={}
for words in sentences:
    for word in words:
        list2=head_word.get(word['upos'],[])
        y=(word['misc'])['ChunkType']
        if(y=='head'):
                list2.append(word['form'])
                head_word[word['upos']]=list2
        else:
                continue

# %%
# sort the dict and calculate freq of pos tag
m1={}
freq_pos_head={}
for k,v in head_word.items():
    t1 =len(v)
    m1[k] = t1
    freq_pos_head = sorted(m1.items(), key=lambda x:x[1],reverse=True)
freq_pos_head
# Out:
# [('NOUN', 55382),
#  ('VERB', 27180),
#  ('PROPN', 19680),
#  ('PUNCT', 13271),
#  ('PRON', 11016),
#  ('ADJ', 6502),
#  ('SCONJ', 5382),
#  ('CCONJ', 5109),
#  ('AUX', 2742),
#  ('ADV', 1940),
#  ('NUM', 356),
#  ('DET', 290),
#  ('ADP', 237),
#  ('X', 110),
#  ('PART', 35),
#  ('INTJ', 3)]

# %% [markdown]
# ### (f)  Find the directed POS tag tuples (ti,tj),for each such 2-tuple, list the frequencies separately for each relation             R as well as total

# %%
#dict contain the tuple of tag and corresponding relation by finding the value of head word with which we find the relation of words
Rel_dict={}
for words in sentences:
    for word in words:
        p=word['head']
        list3=Rel_dict.get((word['upos'],(words[p-1])['upos']),[])
        list3.append(word['deprel'])
        Rel_dict[(word['upos'],(words[p-1])['upos'])]=list3

# %%
# here we sort the dict
Rel_dict2 = {}
for k,v in Rel_dict.items():
    t2= dict(Counter(v))
    marklist = sorted(t2.items(), key=lambda x:x[1],reverse=True)
    Rel_dict2[k] = marklist
print(Rel_dict2)
# Out:
# {('DET', 'PROPN'): [('det', 36)], ('PROPN', 'NOUN'): [('nmod', 6594), ('nsubj', 210), ('conj', 133), ('iobj', 4), ('obj', 4), ('obl', 3), ('dislocated', 2), ('acl:relcl', 1)], ('ADP', 'PROPN'): [('case', 15739), ('dislocated', 171), ('nmod', 3), ('nsubj', 2), ('conj', 2)], ('ADV', 'ADJ'): [('advmod', 259), ('nmod', 7)], ('ADJ', 'NOUN'): [('amod', 9565), ('acl:relcl', 21), ('nmod', 21), ('conj', 11), ('advmod', 10), ('acl', 4), ('dislocated', 1), ('nsubj', 1)], ('NOUN', 'NUM'): [('nmod', 40), ('nsubj', 21), ('conj', 16), ('acl:relcl', 1)], ('ADP', 'NOUN'): [('case', 35024), ('dislocated', 47), ('compound', 1), ('conj', 1), ('nmod', 1)], ('NUM', 'PUNCT'): [('root', 18)], ('AUX', 'NUM'): [('cop', 28)], ('PUNCT', 'NUM'): [('punct', 125)], ('PRON', 'VERB'): [('obl', 3270), ('nsubj', 2918), ('obj', 892), ('iobj', 256), ('nsubj:pass', 55), ('xcomp', 26), ('conj', 9), ('compound', 8), ('acl', 7)], ('NOUN', 'PROPN'): [('nmod', 2213), ('compound', 474), ('conj', 245), ('nsubj', 38), ('acl:relcl', 7), ('obl', 2), ('obj', 2), ('case', 1), ('mark', 1)], ('PROPN', 'VERB'): [('obl', 4721), ('nsubj', 4588), ('obj', 836), ('iobj', 594), ('nsubj:pass', 133), ('acl', 31), ('xcomp', 24), ('compound', 8), ('conj', 4), ('nmod', 1)], ('VERB', 'PUNCT'): [('root', 11598)], ('AUX', 'VERB'): [('aux', 9219), ('aux:pass', 8856), ('cop', 7), ('conj', 3), ('obj', 1), ('dislocated', 1)], ('PUNCT', 'VERB'): [('punct', 12645), ('cc', 10), ('obl', 1)], ('PRON', 'NOUN'): [('nmod', 2735), ('case', 392), ('nsubj', 376), ('mark', 97), ('dep', 34), ('cc', 29), ('det', 28), ('obl', 21), ('iobj', 16), ('advcl', 12), ('punct', 11), ('amod', 11), ('dislocated', 7), ('obj', 7), ('conj', 5), ('acl', 2), ('acl:relcl', 1)], ('NOUN', 'NOUN'): [('nmod', 10506), ('compound', 5488), ('conj', 1641), ('nsubj', 326), ('acl:relcl', 45), ('obl', 16), ('obj', 8), ('iobj', 5), ('case', 4), ('dislocated', 3), ('vocative', 1), ('root', 1)], ('NOUN', 'ADJ'): [('obl', 433), ('nmod', 423), ('nsubj', 419), ('conj', 38), ('obj', 14), ('iobj', 3)], ('NUM', 'ADJ'): [('nummod', 10), ('nmod', 4), ('advmod', 4), ('nsubj', 2)], ('ADJ', 'PUNCT'): [('root', 531)], ('AUX', 'ADJ'): [('cop', 803)], ('PUNCT', 'ADJ'): [('punct', 798), ('nmod', 1), ('cc', 1)], ('NUM', 'NOUN'): [('nummod', 4315), ('nmod', 85), ('conj', 4), ('acl:relcl', 2), ('nsubj', 1)], ('NOUN', 'PUNCT'): [('root', 950)], ('AUX', 'NOUN'): [('cop', 1664)], ('CCONJ', 'VERB'): [('cc', 1851)], ('NOUN', 'VERB'): [('obl', 14490), ('obj', 8227), ('nsubj', 6864), ('compound', 6812), ('iobj', 1099), ('nsubj:pass', 274), ('xcomp', 225), ('acl', 213), ('conj', 113), ('vocative', 4), ('root', 1)], ('VERB', 'VERB'): [('advcl', 3486), ('obj', 3189), ('conj', 1297), ('obl', 975), ('nsubj', 548), ('acl', 50), ('advmod', 28), ('compound', 23), ('nsubj:pass', 13), ('root', 12), ('iobj', 11), ('xcomp', 8), ('acl:relcl', 2), ('mark', 2), ('vocative', 1), ('amod', 1)], ('ADP', 'VERB'): [('mark', 5690), ('case', 11), ('dislocated', 2), ('conj', 2)], ('VERB', 'NOUN'): [('nmod', 1738), ('acl', 1602), ('amod', 491), ('acl:relcl', 479), ('conj', 158), ('advcl', 63), ('obj', 20), ('compound', 16), ('root', 3), ('nsubj', 2)], ('PUNCT', 'NOUN'): [('punct', 2223), ('cc', 12), ('nmod', 1)], ('ADJ', 'VERB'): [('compound', 3779), ('obj', 335), ('xcomp', 283), ('acl', 106), ('advmod', 49), ('obl', 28), ('conj', 26), ('nsubj', 17), ('amod', 2), ('dep', 1), ('iobj', 1), ('nsubj:pass', 1), ('punct', 1)], ('PROPN', 'PROPN'): [('compound', 11910), ('nmod', 1963), ('conj', 1844), ('nsubj', 13), ('punct', 3), ('dislocated', 3), ('root', 1), ('dep', 1)], ('DET', 'NOUN'): [('det', 5433), ('amod', 91), ('nmod', 16), ('acl:relcl', 11), ('nsubj', 2), ('conj', 1), ('advmod', 1)], ('PART', 'PROPN'): [('dep', 512), ('advmod', 4), ('dislocated', 3), ('nmod', 1)], ('VERB', 'PROPN'): [('acl', 171), ('amod', 106), ('acl:relcl', 37), ('nmod', 34), ('conj', 8), ('nsubj', 1)], ('CCONJ', 'NOUN'): [('cc', 1753)], ('ADJ', 'ADJ'): [('amod', 288), ('conj', 198), ('case', 124), ('compound', 44), (' ...

# %%
#use the Rel_dict2 and calculate the total no of frequency of relation correponding to each tuple
y=0
freq_rel={}
for k,v in Rel_dict2.items():
    for i in range(len(v)):
        y+=(((Rel_dict2[k])[i])[1])

    freq_rel[k]=y
                
                
        
freq_rel=sorted(freq_rel.items(), key=lambda x:x[1], reverse=True)  
freq_rel
# Out:
# [(('PROPN', 'X'), 281057),
#  (('PUNCT', 'AUX'), 281056),
#  (('AUX', 'PUNCT'), 281054),
#  (('DET', 'X'), 281052),
#  (('INTJ', 'PRON'), 281051),
#  (('PUNCT', 'INTJ'), 281049),
#  (('PUNCT', 'SCONJ'), 281047),
#  (('VERB', 'SCONJ'), 281046),
#  (('SCONJ', 'PUNCT'), 281044),
#  (('ADJ', 'DET'), 281043),
#  (('DET', 'NUM'), 281042),
#  (('SCONJ', 'AUX'), 281036),
#  (('PART', 'PUNCT'), 281035),
#  (('NOUN', 'PART'), 281034),
#  (('NOUN', 'AUX'), 281031),
#  (('INTJ', 'VERB'), 281024),
#  (('ADJ', 'AUX'), 281023),
#  (('X', 'DET'), 281022),
#  (('X', 'NUM'), 281018),
#  (('ADJ', 'PART'), 281015),
#  (('PRON', 'PART'), 281013),
#  (('SCONJ', 'PART'), 281011),
#  (('PUNCT', 'CCONJ'), 281008),
#  (('CCONJ', 'X'), 281004),
#  (('ADV', 'PART'), 281003),
#  (('CCONJ', 'PART'), 281001),
#  (('ADP', 'PART'), 281000),
#  (('ADJ', 'NUM'), 280994),
#  (('PART', 'PART'), 280987),
#  (('VERB', 'PART'), 280983),
#  (('X', 'ADV'), 280980),
#  (('X', 'PRON'), 280977),
#  (('ADP', 'ADJ'), 280975),
#  (('CCONJ', 'AUX'), 280965),
#  (('X', 'NOUN'), 280964),
#  (('PUNCT', 'X'), 280959),
#  (('SCONJ', 'NUM'), 280958),
#  (('ADV', 'PUNCT'), 280953),
#  (('ADV', 'PRON'), 280942),
#  (('VERB', 'AUX'), 280936),
#  (('X', 'ADJ'), 280896),
#  (('DET', 'PUNCT'), 280887),
#  (('CCONJ', 'DET'), 280870),
#  (('ADP', 'DET'), 280859),
#  (('ADP', 'ADP'), 280842),
#  (('AUX', 'ADV'), 280833),
#  (('SCONJ', 'ADV'), 280817),
#  (('DET', 'DET'), 280813),
#  (('PUNCT', 'PART'), 280787),
#  (('ADV', 'PROPN'), 280777),
#  (('CCONJ', 'ADV'), 280761),
#  (('PROPN', 'DET'), 280750),
#  (('SCONJ', 'PRON'), 280745),
#  (('ADJ', 'PRON'), 280721),
#  (('VERB', 'ADV'), 280690),
#  (('SCONJ', 'SCONJ'), 280656),
#  (('PRON', 'X'), 280653),
#  (('VERB', 'DET'), 280651),
#  (('SCONJ', 'PROPN'), 280644),
#  (('NUM', 'DET'), 280623),
#  (('AUX', 'X'), 280588),
#  (('NOUN', 'X'), 280585),
#  (('SCONJ', 'X'), 280580),
#  (('CCONJ', 'NUM'), 280577),
#  (('PUNCT', 'ADP'), 280558),
#  (('PUNCT', 'DET'), 280555),
#  (('PRON', 'DET'), 280527),
#  (('CCONJ', 'PRON'), 280499),
#  (('AUX', 'DET'), 280475),
#  (('NOUN', 'DET'), 280432),
#  (('SCONJ', 'DET'), 280299),
#  (('PRON', 'ADV'), 280288),
#  (('AUX', 'PROPN'), 280269),
#  (('PROPN', 'PUNCT'), 280190),
#  (('X', 'VERB'), 280134),
#  (('DET', 'ADV'), 280025),
#  (('PRON', 'PROPN'), 279915),
#  (('PROPN', 'NUM'), 279813),
#  (('NUM', 'PRON'), 279785),
#  (('PRON', 'NUM'), 279782),
#  (('PROPN', 'ADV'), 279774),
#  (('PUNCT', 'ADV'), 279757),
#  (('VERB', 'NUM'), 279654),
#  (('NOUN', 'ADV'), 279648),
#  (('VERB', 'ADJ'), 279548),
#  (('ADV', 'DET'), 279263),
#  (('NUM', 'PROPN'), 279182),
#  (('SCONJ', 'CCONJ'), 279104),
#  (('CCONJ', 'CCONJ'), 279103),
#  (('PRON', 'PRON'), 279102),
#  (('DET', 'PRON'), 278991),
#  (('PART', 'ADJ'), 278948),
#  (('SCONJ', 'NOUN'), 278793),
#  (('SCONJ', 'ADJ'), 278247),
#  (('ADJ', 'ADV'), 278031),
#  (('ADV', 'NOUN'), 277977),
#  (('PART', 'ADV'), 277830),
#  (('ADV', 'ADV'), 277649),
#  (('ADP', 'ADV'), 277592),
#  (('VERB', 'PRON'), 277373),
#  (('AUX', 'PRON'), 276735),
#  (('PRON', 'PUNCT'), 276641),
#  (('PROPN', 'PRON'), 276581),
#  (('SCONJ', 'VERB'), 276541),
#  (('DET', 'VERB'), 271991),
#  (('PUNCT', 'PRON'), 271854),
#  (('NOUN', 'PRON'), 271697),
#  (('ADV', 'VERB'), 271461),
#  (('PART', 'VERB'), 269344),
#  (('PART', 'PRON'), 267544),
#  (('AUX', 'AUX'), 267041),
#  (('ADJ', 'PROPN'), 267039),
#  (('NUM', 'VERB'), 266314),
#  (('ADP', 'NUM'), 266196),
#  (('NUM', 'NUM'), 265967),
#  (('CCONJ', 'PROPN'), 265314),
#  (('PUNCT', 'PROPN'), 264122),
#  (('PROPN', 'ADJ'), 261582),
#  (('PRON', 'ADJ'), 261069),
#  (('PART', 'NUM'), 260769),
#  (('PART', 'NOUN'), 260470),
#  (('CCONJ', 'ADJ'), 258424),
#  (('ADP', 'PRON'), 258179),
#  (('PART', 'DET'), 256144),
#  (('DET', 'ADJ'), 256043),
#  (('ADJ', 'ADJ'), 255893),
#  (('CCONJ', 'NOUN'), 255049),
#  (('VERB', 'PROPN'), 253296),
#  (('PART', 'PROPN'), 252939),
#  (('DET', 'NOUN'), 252419),
#  (('PROPN', 'PROPN'), 246864),
#  (('ADJ', 'VERB'), 231126),
#  (('PUNCT', 'NOUN'), 226497),
#  (('VERB', 'NOUN'), 224261),
#  (('ADP', 'VERB'), 219689),
#  (('VERB', 'VERB'), 213984),
#  (('NOUN', 'VERB'), 204338),
#  (('CCONJ', 'VERB'), 166016),
#  (('AUX', 'NOUN'), 164165),
#  (('NOUN', 'PUNCT'), 162501),
#  (('NUM', 'NOUN'), 161551),
#  (('PUNCT', 'ADJ'), 157144),
#  (('AUX', 'ADJ'), 156344),
#  (('ADJ', 'PUNCT'), 155541),
#  (('NUM', 'ADJ'), 155010),
#  (('NOUN', 'ADJ'), 154990),
#  (('NOUN', 'NOUN'), 153660),
#  (('PRON', 'NOUN'), 135616),
#  (('PUNCT', 'VERB'), 131832),
#  (('AUX', 'VERB'), 119176),
#  (('VERB', 'PUNCT'), 101089),
#  (('PROPN', 'VERB'), 89491),
#  (('NOUN', 'PROPN'), 78551),
#  (('PRON', 'VERB'), 75568),
#  (('PUNCT', 'NUM'), 68127),
#  (('AUX', 'NUM'), 68002),
#  (('NUM', 'PUNCT'), 67974),
#  (('ADP', 'NOUN'), 67956),
#  (('NOUN', 'NUM'), 32882),
#  (('ADJ', 'NOUN'), 32804),
#  (('ADV', 'ADJ'), 23170),
#  (('ADP', 'PROPN'), 22904),
#  (('PROPN', 'NOUN'), 6987),
#  (('DET', 'PROPN'), 36)]

# %% [markdown]
# ### (g) For each dependency relation R, list the frequencies separately for each 2-tuple (ti,tj)  as well as total.

# %%
#we use head word and find the pair which contain the relation and make dict contain the relation and corresponding tuple
Rel_dict3={}

for words in sentences:
    for word in words:
        p=word['head']
        list4=Rel_dict3.get(word['deprel'],[])
        list4.append((word['upos'],(words[p-1])['upos']))
        Rel_dict3[word['deprel']]=list4

# %%
Rel_dict3
# Out:
# {'det': [('DET', 'PROPN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'ADJ'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'ADJ'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'ADJ'),
#   ('DET', 'PRON'),
#   ('DET', 'ADJ'),
#   ('DET', 'ADJ'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('ADJ', 'ADJ'),
#   ('DET', 'NOUN'),
#   ('DET', 'ADJ'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'ADJ'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'ADJ'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'PRON'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'PRON'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'ADJ'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('ADJ', 'ADJ'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'ADV'),
#   ('DET', 'ADJ'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'ADJ'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'ADJ'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'ADJ'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'ADJ'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'ADJ'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('ADJ', 'ADJ'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'PRON'),
#   ('DET', 'ADJ'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'PRON'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'ADJ'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'ADV'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'PROPN'),
#   ('DET', 'NOUN'),
#   ('DET', 'ADV'),
#   ('DET', 'ADJ'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'ADJ'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'PROPN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'ADV'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'ADV'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'ADJ'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'ADJ'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'PRON'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'ADV'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'PROPN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'ADJ'),
#   ('ADJ', 'ADJ'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('ADJ', 'ADJ'),
#   ('DET', 'ADV'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'ADV'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'ADJ'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'ADV'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('ADJ', 'ADJ'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'ADJ'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'PROPN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'ADJ'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'PRON'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'ADV'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'ADV'),
#   ('DET', 'ADV'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'ADV'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'DET'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'ADV'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'ADV'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'PRON'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('NUM', 'NUM'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'ADV'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('ADJ', 'ADJ'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'ADJ'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'PRON'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('NUM', 'NUM'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'ADV'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'ADJ'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'PRON'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'ADV'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'ADV'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'ADV'),
#   ('DET', 'PRON'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'ADJ'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'PROPN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'ADV'),
#   ('DET', 'ADV'),
#   ('DET', 'NOUN'),
#   ('DET', 'ADV'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'ADJ'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'ADV'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'ADV'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'ADV'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'ADV'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('DET', 'NOUN'),
#   ...],
#  'nmod': [('PROPN', 'NOUN'),
#   ('NOUN', 'NUM'),
#   ('PRON', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'ADJ'),
#   ('PROPN', 'PROPN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'ADJ'),
#   ('NOUN', 'NOUN'),
#   ('VERB', 'NOUN'),
#   ('NOUN', 'NUM'),
#   ('NUM', 'NUM'),
#   ('NUM', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'ADJ'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NUM'),
#   ('NUM', 'NUM'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'PROPN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'PROPN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'PROPN'),
#   ('PRON', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('PRON', 'ADJ'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'PROPN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'PRON'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('VERB', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'PROPN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'PRON'),
#   ('NOUN', 'PROPN'),
#   ('PROPN', 'PROPN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('VERB', 'PROPN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'PROPN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'PROPN'),
#   ('PROPN', 'ADJ'),
#   ('PRON', 'ADJ'),
#   ('VERB', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'PROPN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'PROPN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'PROPN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('ADV', 'NOUN'),
#   ('ADV', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NUM'),
#   ('PRON', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'ADJ'),
#   ('ADJ', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'ADJ'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('ADV', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PRON', 'PRON'),
#   ('PRON', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'ADJ'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'ADJ'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'ADJ'),
#   ('VERB', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'ADJ'),
#   ('ADV', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('VERB', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('VERB', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'PROPN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'PRON'),
#   ('PRON', 'PRON'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'ADV'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'PRON'),
#   ('NOUN', 'PRON'),
#   ('PRON', 'NUM'),
#   ('PROPN', 'NUM'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('PRON', 'PROPN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'PROPN'),
#   ('PRON', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('PROPN', 'ADJ'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'ADJ'),
#   ('PROPN', 'PROPN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'PROPN'),
#   ('PROPN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'PROPN'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('PRON', 'ADJ'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'ADJ'),
#   ('VERB', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NUM', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'PROPN'),
#   ('PRON', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'ADJ'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('PRON', 'PROPN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'ADJ'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'ADJ'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PRON', 'ADJ'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('ADV', 'NOUN'),
#   ('NOUN', 'ADJ'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'ADJ'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'PROPN'),
#   ('PRON', 'ADJ'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'ADJ'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('VERB', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'PROPN'),
#   ('NOUN', 'PRON'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'ADJ'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'ADJ'),
#   ('NUM', 'ADJ'),
#   ('NOUN', 'ADJ'),
#   ('PRON', 'NOUN'),
#   ('DET', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NUM', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'PRON'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'PROPN'),
#   ('PRON', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'PROPN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PRON', 'ADJ'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'PROPN'),
#   ('PROPN', 'PROPN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'ADJ'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'PROPN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'PROPN'),
#   ('NOUN', 'PRON'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'PROPN'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'PROPN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'PROPN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'PROPN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'PROPN'),
#   ('PROPN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NUM'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'PROPN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'PROPN'),
#   ('PRON', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'PROPN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'PROPN'),
#   ('PROPN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'PROPN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'ADJ'),
#   ('NOUN', 'ADJ'),
#   ('NOUN', 'ADJ'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'PROPN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'PROPN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'PROPN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'PROPN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'PROPN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'PRON'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'PROPN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'ADJ'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'PROPN'),
#   ('NOUN', 'ADJ'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'PROPN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'ADJ'),
#   ('NOUN', 'PRON'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'ADJ'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'ADJ'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'ADJ'),
#   ('NOUN', 'PROPN'),
#   ('PROPN', 'PROPN'),
#   ('PRON', 'ADJ'),
#   ('NOUN', 'PROPN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'PROPN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'PROPN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'ADJ'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'PROPN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NUM', 'NOUN'),
#   ('PROPN', 'ADJ'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('VERB', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NUM', 'NUM'),
#   ('NOUN', 'NOUN'),
#   ('VERB', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NUM'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'PROPN'),
#   ('PROPN', 'NOUN'),
#   ('NUM', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'PROPN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'ADJ'),
#   ('PRON', 'NOUN'),
#   ('NUM', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'PRON'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'ADJ'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('VERB', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('VERB', 'NOUN'),
#   ('VERB', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'PROPN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'PROPN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'ADJ'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PRON', 'PROPN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'PROPN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('ADV', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'PROPN'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NUM', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'ADJ'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'PROPN'),
#   ('PRON', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'PROPN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'PROPN'),
#   ('PROPN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'PRON'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'ADJ'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'ADJ'),
#   ('NOUN', 'ADJ'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NUM'),
#   ('NOUN', 'PROPN'),
#   ('NOUN', 'PROPN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'ADJ'),
#   ('PRON', 'PROPN'),
#   ('PROPN', 'ADJ'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'PROPN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'PROPN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'ADJ'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'PROPN'),
#   ('PROPN', 'ADJ'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NUM'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'PROPN'),
#   ('NOUN', 'PROPN'),
#   ('PRON', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'ADJ'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'ADJ'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PRON', 'ADJ'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'ADJ'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'ADJ'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'ADJ'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('VERB', 'NOUN'),
#   ('PROPN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'PROPN'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ...],
#  'case': [('ADP', 'PROPN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('NOUN', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PRON'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NUM'),
#   ('ADP', 'NUM'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NUM'),
#   ('ADP', 'NUM'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PRON'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'PRON'),
#   ('ADP', 'PRON'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PRON'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PRON'),
#   ('ADP', 'PRON'),
#   ('ADP', 'PRON'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PRON'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PRON'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PRON'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PRON'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PRON'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PRON'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'PRON'),
#   ('ADP', 'ADV'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'ADV'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PRON'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PRON'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NUM'),
#   ('ADP', 'PRON'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PRON'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PRON'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PRON'),
#   ('ADP', 'PRON'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PRON'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'PRON'),
#   ('ADP', 'PRON'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PRON'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PRON'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'PRON'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PRON'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PRON'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PRON'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PRON'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PRON'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PRON'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'PROPN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'NOUN'),
#   ('ADP', 'ADV'),
# ...
#   ('PRON', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('PRON', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('PRON', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'NOUN'),
#   ('VERB', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('VERB', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('VERB', 'VERB'),
#   ('PRON', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'ADJ'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('PRON', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('PRON', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('PRON', 'VERB'),
#   ('PRON', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('PRON', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PRON', 'ADJ'),
#   ('PRON', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('PRON', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('PRON', 'VERB'),
#   ('VERB', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('PRON', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('PRON', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('PRON', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('VERB', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'NOUN'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'ADJ'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('PRON', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('NOUN', 'ADJ'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('PRON', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'NOUN'),
#   ('PROPN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'NOUN'),
#   ('NOUN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('PRON', 'ADJ'),
#   ('PRON', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('PRON', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('PRON', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('PRON', 'VERB'),
#   ('PRON', 'NOUN'),
#   ('PRON', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('PRON', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('PRON', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('PRON', 'NOUN'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PRON', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'ADJ'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('PROPN', 'VERB'),
#   ...],
#  'vocative': [('NOUN', 'VERB'),
#   ('NOUN', 'NOUN'),
#   ('VERB', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB'),
#   ('NOUN', 'VERB')]}

# %%
# here we sort the dictionary 
Rel_dict4 = {}
for k,v in Rel_dict3.items():
    t2= dict(Counter(v))
    marklist = sorted(t2.items(), key=lambda x:x[1],reverse=True)
    Rel_dict4[k] = marklist
print(Rel_dict4)
# Out:
# {'det': [(('DET', 'NOUN'), 5433), (('DET', 'ADJ'), 142), (('DET', 'ADV'), 109), (('DET', 'PRON'), 43), (('DET', 'PROPN'), 36), (('PRON', 'NOUN'), 28), (('ADJ', 'ADJ'), 16), (('DET', 'DET'), 11), (('NUM', 'NUM'), 9), (('PRON', 'PRON'), 3), (('DET', 'NUM'), 2)], 'nmod': [(('NOUN', 'NOUN'), 10506), (('PROPN', 'NOUN'), 6594), (('PRON', 'NOUN'), 2735), (('NOUN', 'PROPN'), 2213), (('PROPN', 'PROPN'), 1963), (('VERB', 'NOUN'), 1738), (('NOUN', 'ADJ'), 423), (('PRON', 'ADJ'), 151), (('NOUN', 'PRON'), 122), (('PROPN', 'ADJ'), 105), (('NUM', 'NOUN'), 85), (('ADV', 'NOUN'), 75), (('PRON', 'PROPN'), 74), (('NUM', 'NUM'), 48), (('NOUN', 'ADV'), 43), (('PRON', 'PRON'), 42), (('NOUN', 'NUM'), 40), (('VERB', 'PROPN'), 34), (('NOUN', 'DET'), 34), (('PROPN', 'PRON'), 30), (('PROPN', 'NUM'), 25), (('ADJ', 'NOUN'), 21), (('ADJ', 'PRON'), 19), (('ADJ', 'ADJ'), 18), (('DET', 'NOUN'), 16), (('PRON', 'ADV'), 15), (('PROPN', 'ADV'), 14), (('VERB', 'ADJ'), 9), (('VERB', 'PRON'), 9), (('PRON', 'DET'), 8), (('ADV', 'ADJ'), 7), (('PRON', 'NUM'), 6), (('NUM', 'ADJ'), 4), (('ADV', 'PROPN'), 4), (('NUM', 'PROPN'), 3), (('ADP', 'PROPN'), 3), (('NOUN', 'X'), 3), (('PROPN', 'DET'), 2), (('VERB', 'DET'), 2), (('NOUN', 'PART'), 2), (('PRON', 'X'), 1), (('PUNCT', 'ADJ'), 1), (('ADV', 'PRON'), 1), (('ADV', 'DET'), 1), (('DET', 'DET'), 1), (('PUNCT', 'NOUN'), 1), (('VERB', 'NUM'), 1), (('ADV', 'ADV'), 1), (('PART', 'PROPN'), 1), (('PROPN', 'VERB'), 1), (('ADP', 'NOUN'), 1), (('VERB', 'ADV'), 1)], 'case': [(('ADP', 'NOUN'), 35024), (('ADP', 'PROPN'), 15739), (('ADP', 'PRON'), 2033), (('PRON', 'NOUN'), 392), (('NUM', 'NUM'), 263), (('ADP', 'NUM'), 228), (('ADP', 'ADV'), 208), (('ADJ', 'ADJ'), 124), (('PRON', 'PRON'), 21), (('ADP', 'DET'), 17), (('ADP', 'VERB'), 11), (('ADP', 'ADJ'), 10), (('ADV', 'ADV'), 9), (('DET', 'DET'), 6), (('NOUN', 'ADV'), 5), (('NOUN', 'NOUN'), 4), (('PRON', 'PROPN'), 3), (('NOUN', 'PROPN'), 1)], 'advmod': [(('PART', 'VERB'), 1425), (('ADV', 'VERB'), 859), (('ADV', 'ADJ'), 259), (('PART', 'NOUN'), 239), (('PART', 'ADJ'), 83), (('ADV', 'DET'), 80), (('ADJ', 'VERB'), 49), (('ADV', 'NOUN'), 42), (('VERB', 'ADJ'), 34), (('NUM', 'DET'), 33), (('VERB', 'VERB'), 28), (('DET', 'VERB'), 20), (('ADJ', 'NOUN'), 10), (('PART', 'PRON'), 10), (('ADJ', 'ADJ'), 9), (('DET', 'ADJ'), 6), (('PART', 'DET'), 5), (('X', 'ADJ'), 5), (('ADV', 'PRON'), 5), (('NUM', 'NUM'), 5), (('NUM', 'ADJ'), 4), (('PART', 'PROPN'), 4), (('PART', 'ADV'), 3), (('ADV', 'ADV'), 3), (('X', 'DET'), 3), (('ADJ', 'PROPN'), 2), (('ADV', 'PROPN'), 2), (('VERB', 'ADV'), 1), (('ADJ', 'ADV'), 1), (('PART', 'NUM'), 1), (('DET', 'NOUN'), 1)], 'amod': [(('ADJ', 'NOUN'), 9565), (('ADJ', 'PROPN'), 718), (('VERB', 'NOUN'), 491), (('ADJ', 'ADJ'), 288), (('VERB', 'PROPN'), 106), (('DET', 'NOUN'), 91), (('ADJ', 'ADV'), 52), (('ADV', 'NOUN'), 20), (('NUM', 'NUM'), 15), (('VERB', 'PRON'), 11), (('PRON', 'NOUN'), 11), (('ADJ', 'PRON'), 5), (('ADJ', 'NUM'), 5), (('PART', 'NOUN'), 4), (('PRON', 'PROPN'), 2), (('ADV', 'PROPN'), 2), (('X', 'NOUN'), 2), (('ADJ', 'VERB'), 2), (('INTJ', 'PRON'), 2), (('VERB', 'NUM'), 1), (('ADJ', 'PART'), 1), (('DET', 'VERB'), 1), (('VERB', 'ADV'), 1), (('DET', 'ADV'), 1), (('DET', 'X'), 1), (('VERB', 'VERB'), 1)], 'root': [(('VERB', 'PUNCT'), 11598), (('NOUN', 'PUNCT'), 950), (('ADJ', 'PUNCT'), 531), (('PRON', 'PUNCT'), 60), (('PROPN', 'PUNCT'), 56), (('VERB', 'AUX'), 36), (('NUM', 'PUNCT'), 18), (('DET', 'PUNCT'), 17), (('VERB', 'VERB'), 12), (('ADV', 'PUNCT'), 11), (('NOUN', 'AUX'), 4), (('VERB', 'NOUN'), 3), (('AUX', 'PUNCT'), 2), (('PROPN', 'PROPN'), 1), (('NOUN', 'NOUN'), 1), (('ADJ', 'AUX'), 1), (('NOUN', 'VERB'), 1), (('PART', 'PUNCT'), 1), (('SCONJ', 'PUNCT'), 1)], 'cop': [(('AUX', 'NOUN'), 1664), (('AUX', 'ADJ'), 803), (('AUX', 'PRON'), 92), (('AUX', 'PROPN'), 79), (('AUX', 'DET'), 43), (('AUX', 'NUM'), 28), (('AUX', 'ADV'), 16), (('AUX', 'VERB'), 7), (('AUX', 'X'), 3), (('SCONJ', 'VERB'), 1)], 'punct': [(('PUNCT', 'VERB'), 12645), (('PUNCT', 'PROPN'), 2532), (('PUNCT',  ...

# %%
#use the Rel_dict4 and calculate the total no of frequency of tuple correponding to each relation
y=0
freq_rel2={}
for k,v in Rel_dict4.items():
    for i in range(len(v)):
        y+=(((Rel_dict4[k])[i])[1])

    freq_rel2[k]=y
                
freq_rel2=sorted(freq_rel2.items(), key=lambda x:x[1], reverse=True)  
freq_rel2
# Out:
# [('vocative', 281057),
#  ('iobj', 281051),
#  ('xcomp', 279056),
#  ('nsubj:pass', 278433),
#  ('dislocated', 277954),
#  ('aux:pass', 277685),
#  ('acl:relcl', 268823),
#  ('dep', 267861),
#  ('acl', 263935),
#  ('conj', 261389),
#  ('mark', 255486),
#  ('advcl', 243871),
#  ('obl', 240253),
#  ('cc', 215078),
#  ('nummod', 209856),
#  ('aux', 205382),
#  ('nsubj', 196152),
#  ('compound', 179146),
#  ('obj', 150212),
#  ('punct', 136605),
#  ('cop', 117857),
#  ('root', 115121),
#  ('amod', 101817),
#  ('advmod', 90418),
#  ('case', 87187),
#  ('nmod', 33089),
#  ('det', 5832)]
